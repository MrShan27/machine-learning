# %% [markdown]
# <a href="https://colab.research.google.com/github/MrShan27/machine-learning/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={"product":["laptop","phone", "Tablet", "phone", "Tablet"], " Region":["Madurai", "Trichy", "Dindigul", "Trichy", "Madurai"],"Price":[50000, 10000,5000,2000,100000], "sales":[3, 2,1,4,2]}

# %%
df=pd.DataFrame(data)
print("Dataset created")
print(df)
# Out:
# Dataset created
#   product    Region   Price  sales
# 0  laptop   Madurai   50000      3
# 1   phone    Trichy   10000      2
# 2  Tablet  Dindigul    5000      1
# 3   phone    Trichy    2000      4
# 4  Tablet   Madurai  100000      2

# %%
filename="E-shop.xlsx"
df. to_excel(filename,index=False)
print(f"File'{filename}'saved Succesfully!")
# Out:
# File'E-shop.xlsx'saved Succesfully!

# %%
df_read=pd.read_excel("E-shop.xlsx")
print (df_read)
# Out:
#   product    Region   Price  sales
# 0  laptop   Madurai   50000      3
# 1   phone    Trichy   10000      2
# 2  Tablet  Dindigul    5000      1
# 3   phone    Trichy    2000      4
# 4  Tablet   Madurai  100000      2

# %%
df["Total revenue "]=df["sales"]*df["Price"]
print(df)
# Out:
#   product    Region   Price  sales  Total revenue
# 0  laptop   Madurai   50000      3          150000
# 1   phone    Trichy   10000      2           20000
# 2  Tablet  Dindigul    5000      1            5000
# 3   phone    Trichy    2000      4            8000
# 4  Tablet   Madurai  100000      2          200000

# %%
df_sorted=df.sort_values(by="Total revenue ", ascending=False)
print(df_sorted)
# Out:
#   product    Region   Price  sales  Total revenue
# 4  Tablet   Madurai  100000      2          200000
# 0  laptop   Madurai   50000      3          150000
# 1   phone    Trichy   10000      2           20000
# 3   phone    Trichy    2000      4            8000
# 2  Tablet  Dindigul    5000      1            5000

# %%
df_filtered=df_read[df["Total revenue "]>50000]
print (df_filtered)
# Out:
#   product   Region   Price  sales
# 0  laptop  Madurai   50000      3
# 4  Tablet  Madurai  100000      2

# %%
filename="E-shop.xlsx"
df_filtered. to_excel(filename,index=False)
print(f"File'{filename}'saved Succesfully!")
# Out:
# File'E-shop.xlsx'saved Succesfully!

# %%
updated_filename="sales_data_updated.xlsx"
df_sorted.to_excel(updated_filename, index=False)

# %%
import matplotlib.pyplot as plt
bikes=["ns200","pulser","r15","appachi","discover","mt15"]
votes=[50,38,29,48,41,67]
plt.bar(bikes,votes,color=['red','green','blue','black','gray','silver'])
plt.xlabel("Bikes")
plt.ylabel("votes")
plt.title("Favouritr bikes")
plt.show()

# %%
import matplotlib.pyplot as plt
players=["dhoni","kohli","rohit","pandiya"]
votes=[10,7,2,12]
plt.pie(votes,labels=players,autopct='%1.1f%%',colors=['yellow','red','blue','green'])
plt.title("Favourit players")
plt.show()

# %%
year=[2010,2014,2016,2018,2020,2023]
collection=[100,120,150,200,250,300]
plt.plot(year,collection,marker='o',linestyle='-',color='green')
plt.xlabel("year")
plt.ylabel("Box office collection(crores)")
plt.title("vijay movie collection")
plt.show()

# %%
movie_durations=[120,135,145,155,140,130,170,180,125,165]
plt.hist(movie_durations, bins=10, color='green', edgecolor='black')
plt.xlabel("Duration (minutes)")
plt.ylabel("Number of movies")
plt.title("Movie_duration_distrubition")
plt.show()

# %%
districts=["chennai","madurai","coimbatore","trichy","salem"]
tea_lovers=[50,32,63,56,43]
coffee_lovers=[45,27,56,33,67]
plt.scatter(tea_lovers, coffee_lovers, color='brown')
plt.xlabel("tea_lovers")
plt.ylabel("coffee_lovers")
plt.title("Tea vs coffee")
plt.show()

# %%
import matplotlib.pyplot as plt
temperatures=[32,35,40,42,39,38,41,37,36,34,33,31]
plt.boxplot(temperatures)
plt.xlabel("chennai")
plt.ylabel("Temperature (oC)")
plt.title("chennai summer Temperatures")
plt.show()

# %%
year=[2010,2012,2014,2016,2018,2020]
population=[26,29,35,39,48,48]
plt.fill_between(year,population,color='green',alpha=0.5)
plt.xlabel("year")
plt.ylabel("population(millions)")
plt.title("Tamil nadu population growth")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
rainfall=np.array([[80,120,200],[90,140,180],[70,100,150]])
cities=["chennai","madurai","coimbatore"]
months=["june","july","august"]
sns.heatmap(rainfall,annot=True,cmap="Blues",xticklabels=months,yticklabels=cities)
plt.title("Tamil Nadu Rainfall")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data={"Name":["shan","ansari","adhi","mani","bala","alagu"],"Age":[20,25,30,22,28,40],"Year of experience":[2,1,8,1,4,10],"Salary":["20k","40K","30K","150K","20K","80K"],"Department":["IT","HR","Finance","IT","Finance","HR"],"Perfomance":[10,8,6,9,6,7]}

# %%
df=pd.DataFrame(data)
print("Dataset created")
print(df)
# Out:
# Dataset created
#      Name  Age  Year of experience Salary Department  Perfomance
# 0    shan   20                   2    20k         IT          10
# 1  ansari   25                   1    40K         HR           8
# 2    adhi   30                   8    30K    Finance           6
# 3    mani   22                   1   150K         IT           9
# 4    bala   28                   4    20K    Finance           6
# 5   alagu   40                  10    80K         HR           7

# %%
filename="company_data.xlsx"
df. to_excel(filename,index=False)
print(f"File'{filename}'saved Succesfully!")
# Out:
# File'company_data.xlsx'saved Succesfully!

# %%
Name=["shan","ansari","adhi","mani","bala","alagu"]
Age=[20,25,30,22,28,40]
Year_of_experience=["2yr","1yr","8yr","1yr","4yr","10yr"]
Salary=["20k","40K","30K","150K","20K","80K"]
Department=["IT","HR","Finance","IT","Finance","HR"]
Perfomance=[10,8,6,9,6,7]

# %%
plt.bar(Name,Year_of_experience,color=['red','green','blue','black','gray','silver'])
plt.xlabel("Name")
plt.ylabel("Year_of_experience")
plt.title("Name vs Year_of_experience")
plt.show ()
plt.pie(Perfomance,labels=Name,autopct='%1.1f%%',colors=['yellow','red','blue','green','orange','grey'])
plt.title("Perfomance")
plt.show ()
plt.plot(Name,Salary,marker='o',linestyle='-',color='green')
plt.xlabel("Name")
plt.ylabel("Salary(Thousands)")
plt.title("Name vs Salary")
plt.show()
plt.scatter(Age,Year_of_experience, color='brown')
plt.xlabel("Age")
plt.ylabel("Year_of_experience")
plt.title("Age vs Year_of_experience")
plt.show()

# %%
plt.bar(Name,Salary,color=['red','green','blue','black','gray','silver'])
plt.xlabel("Name")
plt.ylabel("Salary")
plt.title("Name vs Salary")
plt.show ()

# %%
plt.bar(Name,Perfomance,color=['red','green','blue','black','gray','silver'])
plt.xlabel("Name")
plt.ylabel("Perfomance")
plt.title("Name vs Perfomance")
plt.show ()

# %%
plt.bar(Name,Age,color=['red','green','blue','black','gray','silver'])
plt.xlabel("Name")
plt.ylabel("Age")
plt.title("Name vs Age")
plt.show ()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_excel('Salary.xlsx')
print(data)
# Out:
#     Year of experience  Salary
# 0                    1      20
# 1                    2      30
# 2                    3      40
# 3                    4      50
# 4                    5      60
# 5                    6      70
# 6                    7      80
# 7                    8      90
# 8                    9     100
# 9                   10     110
# 10                  11     120

# %%
data.head()
# Out:
#    Year of experience  Salary
# 0                   1      20
# 1                   2      30
# 2                   3      40
# 3                   4      50
# 4                   5      60

# %%
independent=data[["Year of experience"]]
dependent=data[["Salary"]]

# %%
plt.scatter(independent, dependent)
plt.xlabel('Year of experience')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size = 1/3, random_state = 0)

# %%
import numpy as np
from sklearn import linear_model
regressor=linear_model.RidgeCV(alphas=np.logspace(-6, 6, 13))
regressor.fit(X_train, Y_train)

weight=regressor.coef_
print("weight of the model={}".format(weight))
bias=regressor.intercept_
print("Bias of the model={}".format(bias))
# Out:
# weight of the model=[9.99999967]
# Bias of the model=[10.00000177]

# %%
Y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,Y_pred)
print("r_score=",r_score)
# Out:
# r_score= 0.9999999999999984

# %%
import pickle
filename="finalModel.sav"
pickle.dump(regressor,open(filename, 'wb'))

# %%
load_model=pickle.load(open(filename, 'rb'))

# %%
result=load_model.predict([[30]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RidgeCV was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([309.99999174])

# %%
Prediction_input=int(input("Enter the Prediction input value:"))
future_Prediction=regressor.predict([[Prediction_input]])
print("futur_Prediction={}".format(future_Prediction))
# Out:
# Enter the Prediction input value:0
# futur_Prediction=[10.00000177]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RidgeCV was fitted with feature names
#   warnings.warn(

# %%
data=pd.lable
